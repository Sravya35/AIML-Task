# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Universities.csv")
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# 13     PennState  1081     38      54       18     10185        80
# 14     Princeton  1375     91      14        8     30220        95
# 15        Purdue  1005     28      90       19      9066        69
# 16      Stanford  1360     90      20       12     36450        93
# 17      TexasA&M  1075     49      67       25      8704        67
# 18    UCBerkeley  1240     95      40       17     15140        78
# 19      UChicago  1290     75      50       13     38380        87
# 20     UMichigan  1180     65      68       16     15470        85
# 21         UPenn  1285     80      36       11     27553        90
# 22           UVA  1225     77      44       14     13349        92
# 23    UWisconsin  1085     40      69       15     11857        71
# 24          Yale  1375     95      19       11     43514        96

# %%
np.mean(df["SAT"])
# Out:
# 1266.44

# %%
np.median(df["SAT"])
# Out:
# 1285.0

# %%
np.std(df["GradRate"])
# Out:
# 8.874773236539623

# %%
np.var(df["SFRatio"])
# Out:
# 15.881599999999999

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
#visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,3))
plt.title("Graduation Rate")
plt.hist(df["GradRate"])
# Out:
# (array([2., 2., 0., 1., 2., 0., 3., 4., 4., 7.]),
#  array([67., 70., 73., 76., 79., 82., 85., 88., 91., 94., 97.]),
#  <BarContainer object of 10 artists>)

# %%
s = [20,15,10,25,30,35,28,40,45,60]
scores = pd.Series(s)
scores
# Out:
# 0    20
# 1    15
# 2    10
# 3    25
# 4    30
# 5    35
# 6    28
# 7    40
# 8    45
# 9    60
# dtype: int64

# %%
plt.boxplot(scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f3ad46cc0>,
#   <matplotlib.lines.Line2D at 0x21f3ad46f30>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f3ad47230>,
#   <matplotlib.lines.Line2D at 0x21f3ad474d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f3ad46b70>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f3ad477a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f3ad47aa0>],
#  'means': []}

# %%
s = [20,15,10,25,30,35,28,40,45,60,120,150]
scores = pd.Series(s)
scores
# Out:
# 0      20
# 1      15
# 2      10
# 3      25
# 4      30
# 5      35
# 6      28
# 7      40
# 8      45
# 9      60
# 10    120
# 11    150
# dtype: int64

# %%
plt.boxplot(scores, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f3adbcec0>,
#   <matplotlib.lines.Line2D at 0x21f3adbd190>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f3adbd460>,
#   <matplotlib.lines.Line2D at 0x21f3adbd5e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f3adbcbf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f3adbd8e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f3adbdb50>],
#  'means': []}

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# 13     PennState  1081     38      54       18     10185        80
# 14     Princeton  1375     91      14        8     30220        95
# 15        Purdue  1005     28      90       19      9066        69
# 16      Stanford  1360     90      20       12     36450        93
# 17      TexasA&M  1075     49      67       25      8704        67
# 18    UCBerkeley  1240     95      40       17     15140        78
# 19      UChicago  1290     75      50       13     38380        87
# 20     UMichigan  1180     65      68       16     15470        85
# 21         UPenn  1285     80      36       11     27553        90
# 22           UVA  1225     77      44       14     13349        92
# 23    UWisconsin  1085     40      69       15     11857        71
# 24          Yale  1375     95      19       11     43514        96

# %%
plt.figure(figsize=(6,2))
plt.title("Box plot for SAT Score")
plt.boxplot(df["SAT"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f3ae74fb0>,
#   <matplotlib.lines.Line2D at 0x21f3ae75220>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f3ae75490>,
#   <matplotlib.lines.Line2D at 0x21f3ae75730>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f3ae74170>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f3ae759d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f3ae75cd0>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
plt.title("Box plot for Expenses Scores")
plt.boxplot(df["Expenses"], vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f3f67c530>,
#   <matplotlib.lines.Line2D at 0x21f3f67caa0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f3f67c710>,
#   <matplotlib.lines.Line2D at 0x21f3f67d070>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f3f67c260>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f3f67c980>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f3f67d2e0>],
#  'means': []}
